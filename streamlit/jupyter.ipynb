# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor

# %%
dataset = pd.read_parquet('data/yellow_tripdata_2020-01.parquet')

# %%
dataset.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2020-01-01 00:28:15   2020-01-01 00:33:03              1.0
# 1         1  2020-01-01 00:35:39   2020-01-01 00:43:04              1.0
# 2         1  2020-01-01 00:47:41   2020-01-01 00:53:52              1.0
# 3         1  2020-01-01 00:55:23   2020-01-01 01:00:14              1.0
# 4         2  2020-01-01 00:01:58   2020-01-01 00:04:16              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            1.2         1.0                  N           238           239
# 1            1.2         1.0                  N           239           238
# 2            0.6         1.0                  N           238           238
# 3            0.8         1.0                  N           238           151
# 4            0.0         1.0                  N           193           193
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
dataset.isnull().sum()
# Out:
# VendorID                       0
# tpep_pickup_datetime           0
# tpep_dropoff_datetime          0
# passenger_count            65441
# trip_distance                  0
# RatecodeID                 65441
# store_and_fwd_flag         65441
# PULocationID                   0
# DOLocationID                   0
# payment_type                   0
# fare_amount                    0
# extra                          0
# mta_tax                        0
# tip_amount                     0
# tolls_amount                   0
# improvement_surcharge          0
# total_amount                   0
# congestion_surcharge       65441
# airport_fee              6405008
# dtype: int64

# %%
dataset['PULocationID'].sample()
